# %% [markdown]
# # Multiple Linear Regression and Regression Error Metrics

# %% [markdown]
# Simlpe linear regression   = b0 + b1 * X
#
# Multiple linear regression = b0 + b1 * X1 + b2 * X2 + b3 * X3 + ... + bn * Xn
#
# X1 = TV
#
# X2 = Radio
#
# X3 = Newspaper

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import missingno as msno
from scipy.stats import skew
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from yellowbrick.regressor import ResidualsPlot
from yellowbrick.regressor import PredictionError

plt.rcParams["figure.figsize"] = (10, 6)

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.shape
# Out:
# (200, 4)

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
#!pip install missingno

# %%
#import missingno as msno

# %%
msno.matrix(df);

# %%
df.sort_values(by = 'sales', ascending = False)
# Out:
#         TV  radio  newspaper  sales
# 175  276.9   48.9       41.8   27.0
# 183  287.6   43.0       71.8   26.2
# 198  283.6   42.0       66.2   25.5
# 98   289.7   42.3       51.2   25.4
# 147  243.2   49.0       44.3   25.4
# ..     ...    ...        ...    ...
# 108   13.1    0.4       25.6    5.3
# 78     5.4   29.9        9.4    5.3
# 8      8.6    2.1        1.0    4.8
# 155    4.1   11.6        5.7    3.2
# 130    0.7   39.6        8.7    1.6
#
# [200 rows x 4 columns]

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
print(np.mean([100, 110, 120, 115]))  # Outlier yok
print(np.std([100, 110, 120, 115]))
# Out:
# 111.25
# 7.39509972887452

# %%
print(np.mean([100, 110, 120, 700]))  # Outlier var. Std mean'a yaklasinca outlier soz konusu olabilir
print(np.std([100, 110, 120, 700]))
# Out:
# 257.5
# 255.57533136044253

# %%
print(np.mean([100, 110, 120, 900]))  # Outlier var. Std mean'dan yuksekse outlier soz konusu olabilir
print(np.std([100, 110, 120, 900]))
# Out:
# 307.5
# 342.153109002388

# %%
sns.pairplot(data = df);

# %%
sns.heatmap(df.corr(), annot= True);

# %%
# from scipy.stats import skew

# %% [markdown]
# ![Ekran%20Al%C4%B1nt%C4%B1s%C4%B1.JPG](attachment:Ekran%20Al%C4%B1nt%C4%B1s%C4%B1.JPG)

# %%
for i in df.drop(columns = "sales" ).columns:
    print(i, skew(df[i]))
# Out:
# TV -0.06932836662244649
# radio 0.0934668451108453
# newspaper 0.8879959753085498

# %%
for j in df.drop(columns = "sales").columns:
    g = sns.distplot(df[j], color = "b", label = "Skewness : %.2f"%(df[j].skew()))
    g = g.legend(loc = "best")
    plt.show()

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# TV <-> sales        = 0,78 = Kuvvetli (güçlü) doğrusal pozitif ilişki var
#
# Radio <-> sales     = 0,58 = Orta kuvvetli doğrusal pozitif ilişki var
#
# Newspaper <-> sales = 0,23 = Cok düşük kuvvetli (zayıf) doğrusal pozitif ilişki var

# %% [markdown]
# # Train - Test Split

# %%
# !pip install scikit-learn
# !pip install sklearn

# %%
# Teste sokmadan once verilerimizin sayisal degerlerden olustugundan emin olmaliyiz
# Bu datamizda 70-30 olarak ayiracagiz.
# Bu rakamlar max seviyelerdir.
# Datamiz 1000'e kadar ise %30-20 test, %70-80 train olarak ayrilir
# Datamiz 1000 - 100.000'e kadar ise %20-10 test, %80-90 train olarak ayrilir
# Datamiz 100.000 - 1.000.000'a kadar ise %5 test, %95 train olarak ayrilir
# Datamiz 1.000.000'dan buyuk ise %1 test, %99 train olrak ayrilir
# En dusuk oran ise %30 test, %70 train olarak ayrilabilir. Train datasinin fazla olmasi onemlidir

# %%
X = df.drop(columns  = "sales")
y = df["sales"]
print(X,y)
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns] 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
# from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# ![image%20%287%29.png](attachment:image%20%287%29.png)

# %%
print("X Train features shape: {}\ny Train features shape: {}\nX Test features shape : {}\nY Test features shape : {}".format
      (X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X Train features shape: (140, 3)
# y Train features shape: (140,)
# X Test features shape : (60, 3)
# Y Test features shape : (60,)

# %%
#Print("Train features shape: ", X_train.shape)
#Print("Train target shape: ", y_train.shape)
#Print("Test features shape: ", X_test.shape)
#Print("Test target shape: ", y_test.shape)

# %%
X_train
# Out:
#         TV  radio  newspaper
# 169  284.3   10.6        6.4
# 97   184.9   21.0       22.0
# 31   112.9   17.4       38.6
# 12    23.8   35.1       65.9
# 35   290.7    4.1        8.5
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [140 rows x 3 columns]

# %%
y_train
# Out:
# 169    15.0
# 97     15.5
# 31     11.9
# 12      9.2
# 35     12.8
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: sales, Length: 140, dtype: float64

# %% [markdown]
# # Model Fitting and Compare Actual and Predicted Labels

# %%
# from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([16.5653963 , 21.18822792, 21.55107058, 10.88923816, 22.20231988,
#        13.35556872, 21.19692502,  7.35028523, 13.27547079, 15.12449511,
#         9.01443026,  6.52542825, 14.30205991,  8.97026042,  9.45679576,
#        12.00454351,  8.91549403, 16.15619251, 10.29582883, 18.72473553,
#        19.76821818, 13.77469028, 12.49638908, 21.53501762,  7.60860741,
#         5.6119801 , 20.91759483, 11.80627665,  9.08076637,  8.51412012,
#        12.17604891,  9.9691939 , 21.73008956, 12.77770578, 18.1011362 ,
#        20.07590796, 14.26202556, 20.93826535, 10.83938827,  4.38190607,
#         9.51332406, 12.40486324, 10.17045434,  8.09081363, 13.16388427,
#         5.2243552 ,  9.28893833, 14.09330719,  8.69024497, 11.66119763,
#        15.71848432, 11.63156862, 13.35360735, 11.1531472 ,  6.33636845,
#         9.76157954,  9.4195714 , 24.25516546,  7.69519137, 12.15317572])

# %%
model.coef_
# Out:
# array([0.04405928, 0.1992875 , 0.00688245])

# %%
model.intercept_
# Out:
# 2.7089490925159065

# %% [markdown]
# y_pred = b1 * TV + b2 * radio + b3 * newspaper + b0

# %%
X_test.head()
# Out:
#         TV  radio  newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2

# %%
sum(X_test.loc[95] * model.coef_) + model.intercept_
# Out:
# 16.565396297434837

# %%
my_dict = {"Actual": y_test, "pred": y_pred, "residual": y_test - y_pred}

# %%
comparing = pd.DataFrame(my_dict)
comparing
# Out:
#      Actual       pred  residual
# 95     16.9  16.565396  0.334604
# 15     22.4  21.188228  1.211772
# 30     21.4  21.551071 -0.151071
# 158     7.3  10.889238 -3.589238
# 128    24.7  22.202320  2.497680
# 115    12.6  13.355569 -0.755569
# 69     22.3  21.196925  1.103075
# 170     8.4   7.350285  1.049715
# 174    11.5  13.275471 -1.775471
# 45     14.9  15.124495 -0.224495
# 66      9.5   9.014430  0.485570
# 182     8.7   6.525428  2.174572
# 165    11.9  14.302060 -2.402060
# 78      5.3   8.970260 -3.670260
# 186    10.3   9.456796  0.843204
# 177    11.7  12.004544 -0.304544
# 56      5.5   8.915494 -3.415494
# 152    16.6  16.156193  0.443807
# 82     11.3  10.295829  1.004171
# 68     18.9  18.724736  0.175264
# 124    19.7  19.768218 -0.068218
# 16     12.5  13.774690 -1.274690
# 148    10.9  12.496389 -1.596389
# 93     22.2  21.535018  0.664982
# 65      9.3   7.608607  1.691393
# 60      8.1   5.611980  2.488020
# 84     21.7  20.917595  0.782405
# ...

# %%
result_sample = comparing.head(25)
result_sample
# Out:
#      Actual       pred  residual
# 95     16.9  16.565396  0.334604
# 15     22.4  21.188228  1.211772
# 30     21.4  21.551071 -0.151071
# 158     7.3  10.889238 -3.589238
# 128    24.7  22.202320  2.497680
# 115    12.6  13.355569 -0.755569
# 69     22.3  21.196925  1.103075
# 170     8.4   7.350285  1.049715
# 174    11.5  13.275471 -1.775471
# 45     14.9  15.124495 -0.224495
# 66      9.5   9.014430  0.485570
# 182     8.7   6.525428  2.174572
# 165    11.9  14.302060 -2.402060
# 78      5.3   8.970260 -3.670260
# 186    10.3   9.456796  0.843204
# 177    11.7  12.004544 -0.304544
# 56      5.5   8.915494 -3.415494
# 152    16.6  16.156193  0.443807
# 82     11.3  10.295829  1.004171
# 68     18.9  18.724736  0.175264
# 124    19.7  19.768218 -0.068218
# 16     12.5  13.774690 -1.274690
# 148    10.9  12.496389 -1.596389
# 93     22.2  21.535018  0.664982
# 65      9.3   7.608607  1.691393

# %%
result_sample.plot(kind= "bar", figsize = (15,9))
plt.show()

# %% [markdown]
# # Error Metrics

# %%
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
r2_score = r2_score(y_test, y_pred)
r2_score
# Out:
# 0.8609466508230368

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 1.5116692224549086

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 3.79679723671522

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# 1.9485372043446387

# %%
sales_mean = df["sales"].mean()
sales_mean
# Out:
# 14.0225

# %%
mae / sales_mean
# Out:
# 0.10780311802138767

# %%
rmse / sales_mean
# Out:
# 0.138957903679418

# %% [markdown]
# # Adjusted R2 Score (düzenlenmiş R2 skor)

# %%
def adj_r2(y_test, y_pred, df):
    r2 = r2_score(y_test, y_pred)
    n = df.shape[0]   # number of observations gözlem
    p = df.shape[1]-1 # number of independent variables feature
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %%
adj_r2(y_test, y_pred, df)
# Out:
# 0.8588182832335934

# %%
def adj_r2(y_test, y_pred, df):
    r2 = r2_score(y_test, y_pred)
    n = df.shape[0]   # number of observations
    p = 100 # number of independent variables
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %%
adj_r2(y_test, y_pred, df)
# Out:
# 0.7204887223614578

# %% [markdown]
# # What is the Concept of Punishment for RMSE Error Metric?

# %%
variables = {"Actual": [1000, 2000, 3000, 4000, 5000], "pred": [1100, 2200, 3200, 4200, 5300]}
variables2 = {"Actual": [1000, 2000, 3000, 4000, 5000], "pred": [1100, 2200, 3200, 4200, 5800]}

# %%
variables, variables2
# Out:
# ({'Actual': [1000, 2000, 3000, 4000, 5000],
#   'pred': [1100, 2200, 3200, 4200, 5300]},
#  {'Actual': [1000, 2000, 3000, 4000, 5000],
#   'pred': [1100, 2200, 3200, 4200, 5800]})

# %%
df_2 = pd.DataFrame(variables)
df_2
# Out:
#    Actual  pred
# 0    1000  1100
# 1    2000  2200
# 2    3000  3200
# 3    4000  4200
# 4    5000  5300

# %%
df_3 = pd.DataFrame(variables2)
df_3
# Out:
#    Actual  pred
# 0    1000  1100
# 1    2000  2200
# 2    3000  3200
# 3    4000  4200
# 4    5000  5800

# %%
df_2["residual"] = abs(df_2.Actual - df_2.pred)
df_2
# Out:
#    Actual  pred  residual
# 0    1000  1100       100
# 1    2000  2200       200
# 2    3000  3200       200
# 3    4000  4200       200
# 4    5000  5300       300

# %%
df_3["residual"] = abs(df_3.Actual - df_3.pred)
df_3
# Out:
#    Actual  pred  residual
# 0    1000  1100       100
# 1    2000  2200       200
# 2    3000  3200       200
# 3    4000  4200       200
# 4    5000  5800       800

# %%
df_2.residual.sum() / 5 # residualleri topla gözlem sayısına böl
# Out:
# 200.0

# %%
df_3.residual.sum() / 5
# Out:
# 300.0

# %%
((df_2.residual ** 2).sum() / 5) ** 0.5
# Out:
# 209.76176963403032

# %%
((df_3.residual ** 2).sum() / 5) ** 0.5
# Out:
# 392.42833740697165

# %% [markdown]
# Mean Absolute Error (MAE); her bir tahmin ve gerçek değer arasındaki farkın mutlak değerinin ortalamasıdır. Ceza vermiyor.
# Root Mean Square Error (RMSE); tahmin ettiği değerler ile gerçek değerler arasındaki farkların karelerinin ortalamasının kareköküdür. Büyük hataları daha da büyütürken, küçük hataları daha da küçültür. MAE ile RMSE birbirine yakınsa model başarılı diyebiliriz.

# %% [markdown]
# # Evaluation Model

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance: ")
    print("---------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
y_train_pred = model.predict(X_train)

# %%
eval_metric(y_train, y_train_pred)
# Out:
# Model testing performance:
# ---------------------------
# R2_score 	: 0.9055159502227753
# MAE 		: 1.1581502948072526
# MSE 		: 2.4793551789057866
# RMSE 		: 1.574596830590544

# %%
eval_metric(y_test, y_pred)
# Out:
# Model testing performance:
# ---------------------------
# R2_score 	: 0.8609466508230368
# MAE 		: 1.5116692224549086
# MSE 		: 3.79679723671522
# RMSE 		: 1.9485372043446387

# %% [markdown]
# # Is Data Suitable for Linear Regression?

# %%
residuals = y_test - y_pred

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = y_test, y = residuals)
plt.axhline(y = 0, color = "red", linestyle = "--")
plt.show()

# %% [markdown]
# https://stats.stackexchange.com/questions/12262/what-if-residuals-are-normally-distributed-but-y-is-not

# %%
sns.kdeplot(residuals);

# %%
stats.probplot(residuals, dist = "norm", plot = plt);

# %%
skew(residuals)
# Out:
# -0.9865673346742722

# %%
# !pip install yellowbrick
# Out:
# ...
#      ------------------------------------ 282.6/282.6 kB 103.8 kB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -ip (c:\users\yusuf\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\yusuf\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\yusuf\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\yusuf\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\yusuf\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\yusuf\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\yusuf\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# ...

# %%
# from yellowbrick.regressor import ResidualsPlot

# %% [markdown]
# https://www.scikit-yb.org/en/latest/api/regressor/residuals.html

# %%
model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();                 # Finalize and render the figure

# %%
# from yellowbrick.regressor import PredictionError

# %%
model = LinearRegression()
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.show();

# %% [markdown]
# # Retraining Model on Full Data

# %%
final_model = LinearRegression()
final_model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# # Coefficients
